# %%
from Tkinter import *
import pyqrcode
import sqlite3
from PIL import ImageTk, Image


root = Tk()
root.geometry("500x800")
root.title("Application Form")
root.configure(background='lightblue')
f1 = Frame(root)

    #Setting it up
img = ImageTk.PhotoImage(Image.open("INDIANEMBLEM.png"))
img1 = ImageTk.PhotoImage(Image.open("Aadhaar.png"))
img2 = ImageTk.PhotoImage(Image.open("INDIANEMBLEM.jpg"))
img3 = ImageTk.PhotoImage(Image.open("aadhaarcard.jpg"))
img5 = ImageTk.PhotoImage(Image.open("blankimage.jpg"))

Fathername=StringVar()
Fullname=StringVar()
Email=StringVar()
var = IntVar()
c=StringVar()
var1= IntVar()
mobile=IntVar()
HouseNumber=IntVar()
StreetName=StringVar()
City=StringVar()
State=StringVar()
Pincode=IntVar()
dob=StringVar()
cur=[]

def database():
   name1=Fullname.get()
   name2=Fathername.get()
   email=Email.get()
   gender=var.get()
   bloodgroup=c.get()
   mob=mobile.get()
   dateob=dob.get()
   houseno=HouseNumber.get()
   streetname=StreetName.get()
   city=City.get()
   state=State.get() 
   pincode=Pincode.get()
   conn = sqlite3.connect('AadharForm.db')
   with conn:
      cursor=conn.cursor()
   cursor.execute('CREATE TABLE IF NOT EXISTS Iden1 (Id INTEGER PRIMARY KEY AUTOINCREMENT,Fullname TEXT,Fathername TEXT,Email TEXT,Gender TEXT,Bloodgroup TEXT,MobileNumber INTEGER(10),DateofBirth DATE,HouseNumber TEXT,StreetName TEXT,City TEXT,State TEXT,Pincode INTEGER(6))')
   cursor.execute('INSERT INTO Iden1 (FullName,FatherName,Email,Gender,Bloodgroup,MobileNumber,DateofBirth,HouseNumber,StreetName,City,State,Pincode) VALUES(?,?,?,?,?,?,?,?,?,?,?,?)',((name1),(name2),(email),(gender),(bloodgroup),(mob),(dateob),(houseno),(streetname),(city),(state),(pincode),))
   cursor.execute('SELECT Id,FullName,FatherName,Email,Gender,Bloodgroup,MobileNumber,DateofBirth,HouseNumber,StreetName,City,State,Pincode FROM Iden1 WHERE Id='+str(cursor.lastrowid))
   conn.commit()
    
   root1=Toplevel()
   root1.geometry('450x800')
   root1.title("AADHAR CARD")
   root1.configure(background='white')

       
   for row in cursor:
    q=pyqrcode.create(str(row[0])+" "+str(row[0]+3064)+" "+str(row[0]+5067)+"\n"+row[1]+"\n"+str(row[6]))
    q.png('myQR.png',scale=2) 


    img4 = ImageTk.PhotoImage(Image.open("myQR.png"))

    
    #Displaying it
    imglabel = Label(root1, image=img,width=75)
    imglabel.place(x=10,y=10)

    img1label = Label(root1, image=img1,width=140)
    img1label.place(x=295,y=10)

    label_00 = Label(root1,bg="orange",text="",width=300,font=(15),)
    label_00.place(x=0,y=120)

    label_0 = Label(root1,bg="orange",fg="darkred",text="ଭାରତୀୟ ବିଶିଷ୍ଟ ପରିଚୟ ପ୍ରାଧିକରଣ",width=30,font=("bold",15),)
    label_0.place(x=50,y=120)

    label_1 = Label(root1,bg="white",text="ଭାରତ ସରକାର",width=30,font=("bold",17),)
    label_1.place(x=30,y=150)

    label_3 = Label(root1,bg="green",text="",width=300,font=(30),)
    label_3.place(x=0,y=190)

    label_31 = Label(root1,bg="green",text="",width=300,font=(30),)
    label_31.place(x=0,y=197)

    label_2 = Label(root1,bg="white",fg="red",text="Unique Identification Authority of India",width=45,font=("bold",13),)
    label_2.place(x=20,y=177)

    label_32 = Label(root1,bg="green",text="Government of India",width=45,font=("bold",13),)
    label_32.place(x=20,y=200)

    label_4 = Label(root1,bg="white",text="                 ନାମାକଂନ କ୍ରମାକ / Enrolment No.:",width=30,font=("bold",10),)
    label_4.place(x=0,y=227)

    label_41 = Label(root1,bg="white",text="2431/42313/12332",)
    label_41.place(x=250,y=227)

    label_42 = Label(root1,bg="white",text="To",width=30,font=("bold",8),)
    label_42.place(x=0,y=250)

    label_43 = Label(root1,bg="white",text=row[1],width=30,font=("bold",8),)
    label_43.place(x=25,y=265)

    if '2' in row[4]:
        label_44 = Label(root1,bg="white",text="D/O "+str(row[2]),width=20,font=("bold",8),)
        label_44.place(x=68,y=280)
    elif '1' in row[4]:
        label_44 = Label(root1,bg="white",text="S/O "+str(row[2]),width=20,font=("bold",8),)
        label_44.place(x=68,y=280)

    label_43 = Label(root1,bg="white",text=row[8],width=20,font=("bold",8),)
    label_43.place(x=35,y=295)

    label_431 = Label(root1,bg="white",text=row[9],width=20,font=("bold",8),)
    label_431.place(x=50,y=310)

    label_432 = Label(root1,bg="white",text=row[10],width=20,font=("bold",8),)
    label_432.place(x=37,y=325)

    label_433 = Label(root1,bg="white",text=row[11],width=20,font=("bold",8),)
    label_433.place(x=38,y=340)

    label_434 = Label(root1,bg="white",text=row[12],width=20,font=("bold",8),)
    label_434.place(x=45,y=355)

    label_435 = Label(root1,bg="white",text=row[6],width=20,font=("bold",8),)
    label_435.place(x=51,y=370)

    label_44 = Label(root1,bg="red",text="",width=500,font=("bold",1),)
    label_44.place(x=0,y=600)

    label_45 = Label(root1,bg="white",text="ଆପଣଙ୍କ",width=10,font=("bold",10),)
    label_45.place(x=50,y=500)

    label_45 = Label(root1,bg="white",fg="red",text="ଆଧାର",width=5,font=("bold",10),)
    label_45.place(x=115,y=500)

    label_45 = Label(root1,bg="white",text="ସଂଖ୍ୟା / Your",width=10,font=("bold",10),)
    label_45.place(x=155,y=500)

    label_45 = Label(root1,bg="white",fg="red",text="Aadhaar",width=6,font=("bold",10),)
    label_45.place(x=240,y=500)

    label_45 = Label(root1,bg="white",text="No. :",width=5,font=("bold",10),)
    label_45.place(x=300,y=500)

    label_45 = Label(root1,bg="white",text=str(row[0])+" "+str(row[0]+3064)+" "+str(row[0]+5067),width=20,font=("bold",20),)
    label_45.place(x=40,y=530)

    label_45 = Label(root1,bg="white",text="ମୋ",width=5,font=("bold",15),)
    label_45.place(x=85,y=570)

    label_45 = Label(root1,bg="white",fg="red",text="ଆଧାର",width=5,font=("bold",15),)
    label_45.place(x=135,y=570)

    label_45 = Label(root1,bg="white",text=", ମୋ ପରିଚୟ",width=10,font=("bold",15),)
    label_45.place(x=190,y=570)

    label_5 = Label(root1,bg="red",text="",width=500,font=("bold",1),)
    label_5.place(x=0,y=760)

    label_51 = Label(root1,bg="white",text="ମୋ",width=5,font=("bold",13),)
    label_51.place(x=105,y=770)

    label_52 = Label(root1,bg="white",fg="red",text="ଆଧାର",width=5,font=("bold",13),)
    label_52.place(x=155,y=770)

    label_53 = Label(root1,bg="white",text=", ମୋ ପରିଚୟ",width=10,font=("bold",13),)
    label_53.place(x=205,y=770)

    img1label = Label(root1, image=img2,width=40)
    img1label.place(x=15,y=610)

    img3label = Label(root1, image=img3,width=321)
    img3label.place(x=80,y=610)

    label_54 = Label(root1,bg="white",text=row[1],width=10,font=("bold",10),)
    label_54.place(x=100,y=680)

    label_55 = Label(root1,bg="white",text="ଜନ୍ମ ତାରିଖ /DOB:"+str(row[7]),width=25,font=("bold",10),)
    label_55.place(x=82,y=700)
    
    if '2' in row[4]:
      label_55 = Label(root1,bg="white",text="ସ୍ତ୍ରୀ /FEMALE",width=9,font=("bold",10),)
      label_55.place(x=100,y=720)
    elif '1' in row[4]:
      label_55 = Label(root1,bg="white",text="ପୁରୁଷ /MALE",width=9,font=("bold",10),)
      label_55.place(x=100,y=720)
        
    label_56 = Label(root1,bg="white",text=str(row[0])+" "+str(row[0]+3064)+" "+str(row[0]+5067),width=13,font=("bold",13),)
    label_56.place(x=200,y=730)

    img4label = Label(root1,bg="white", image=img4,width=120)
    img4label.place(x=330,y=380)

    img4label = Label(root1,bg="white", image=img4,width=60)
    img4label.place(x=380,y=665)

    img5label = Label(root1,bg="white", image=img5,width=60)
    img5label.place(x=20,y=670)
    
    root1.mainloop()
   # conn.commit()
    conn.close()

             
label_0 = Label(root,bg="lightblue",fg="red", text="Application form",width=20,font=("bold", 20))
label_0.place(x=90,y=53)


label_1 = Label(root,bg="lightblue", text="FullName",width=20,font=("bold", 10))
label_1.place(x=70,y=130)

entry_1 = Entry(root,textvar=Fullname)
entry_1.place(x=240,y=130)
                  
label_2 = Label(root,bg="lightblue", text="FatherName",width=20,font=("bold", 10))
label_2.place(x=70,y=180)

entry_2 = Entry(root,textvar=Fathername)
entry_2.place(x=240,y=180)                  

label_3 = Label(root,bg="lightblue", text="Email",width=20,font=("bold", 10))
label_3.place(x=68,y=230)

entry_3 = Entry(root,textvar=Email)
entry_3.place(x=240,y=230)

label_4 = Label(root,bg="lightblue", text="Gender",width=20,font=("bold", 10))
label_4.place(x=70,y=280)

Radiobutton(root,bg="lightblue", text="Male",padx = 5, variable=var, value=1).place(x=235,y=280)
Radiobutton(root,bg="lightblue", text="Female",padx = 20, variable=var, value=2).place(x=290,y=280)

label_5 = Label(root,bg="lightblue", text="Blood Group",width=20,font=("bold", 10))
label_5.place(x=70,y=330)

list1 = ['A+','A-','B+','B-','O+','O-','AB+','AB-'];

droplist=OptionMenu(root,c, *list1)
droplist.config(width=20)
c.set('select your bloodgroup') 
droplist.place(x=230,y=330)
    
label_6 = Label(root,bg="lightblue", text="Mobile Number",width=20,font=("bold", 10))
label_6.place(x=70,y=380)

entry_6 = Entry(root,textvar=mobile)
entry_6.place(x=240,y=380)


label_7 = Label(root,bg="lightblue", text="Date of Birth",width=20,font=("bold", 10))
label_7.place(x=70,y=430)

entry_7 = Entry(root,textvar=dob)
entry_7.place(x=240,y=430)

label_8 = Label(root,bg="lightblue", text="House Number",width=20,font=("bold", 10))
label_8.place(x=70,y=480)

entry_8 = Entry(root,textvar=HouseNumber)
entry_8.place(x=240,y=480)
            
label_9 = Label(root,bg="lightblue", text="Street Name",width=20,font=("bold", 10))
label_9.place(x=70,y=530)

entry_9 = Entry(root,textvar=StreetName)
entry_9.place(x=240,y=530)
                  
label_10 = Label(root,bg="lightblue", text="City",width=20,font=("bold", 10))
label_10.place(x=70,y=580)

entry_10 = Entry(root,textvar=City)
entry_10.place(x=240,y=580)
                  
label_11 = Label(root,bg="lightblue", text="State",width=20,font=("bold", 10))
label_11.place(x=70,y=630)

entry_11 = Entry(root,textvar=State)
entry_11.place(x=240,y=630)                  
           
                  
label_11 = Label(root,bg="lightblue", text="Pincode",width=20,font=("bold", 10))
label_11.place(x=70,y=680)

entry_11 = Entry(root,textvar=Pincode)
entry_11.place(x=240,y=680)                  


Button(root, text='Submit',width=30,bg='brown',fg='white',command=database).place(x=130,y=750)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Mallick\Anaconda2\lib\lib-tk\Tkinter.py", line 1541, in __call__
#     return self.func(*args)
#   File "<ipython-input-5-34210da3215f>", line 62, in database
#     for row in cursor:
# ProgrammingError: Cannot operate on a closed database.
